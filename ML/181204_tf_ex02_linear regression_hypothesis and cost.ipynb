# %%
import tensorflow as tf

#1. building graph

x_train = [1, 2, 3]
y_train = [1, 2, 3]

# tensorflow가 자체적으로 변경시키는 tainable한 변수
# tenssor var만들때 shape을 정의해야함
# var을 랜덤으로 만들때 random_normal[1] : 1차원

W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = x_train * W + b

#cost/loss function
#cost(W, b) 함수를 표현하는 것
cost = tf.reduce_mean(tf.square(hypothesis - y_train))
## reduce_mean이란 평균내주는 것
## t = [1., 2., 3., 4.]
## tf.reduce_mean(t) ==> 2.5

#cost가 주어졌음. 이제 minimize해야함

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost) # minimize할 것이 무엇인가

# %%
#2. run/update graph and get results
sess = tf.Session()
sess.run(tf.global_variables_initializer()) # tensor var 초기화

for step in range(2001):
    sess.run(train) #train이 제일 상위 노드..? => cost [hyp [w, b]]
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 2.1502392 [0.10593705] [0.51637906]
# 20 0.09442854 [0.6272642] [0.7029602]
# 40 0.06891145 [0.69042087] [0.6900006]
# 60 0.06243371 [0.7093157] [0.65948474]
# 80 0.0567019 [0.72339064] [0.6286735]
# 100 0.051497564 [0.7364297] [0.5991455]
# 120 0.046770915 [0.7488202] [0.5709895]
# 140 0.042478114 [0.7606251] [0.54415536]
# 160 0.038579326 [0.77187485] [0.5185821]
# 180 0.035038333 [0.78259593] [0.4942105]
# 200 0.031822383 [0.7928131] [0.47098455]
# 220 0.02890162 [0.8025501] [0.44885004]
# 240 0.026248923 [0.81182945] [0.42775583]
# 260 0.02383968 [0.82067275] [0.4076529]
# 280 0.02165161 [0.8291005] [0.3884948]
# 300 0.019664321 [0.8371321] [0.37023693]
# 320 0.01785944 [0.8447863] [0.35283723]
# 340 0.016220251 [0.85208076] [0.33625513]
# 360 0.014731489 [0.8590324] [0.32045242]
# 380 0.013379368 [0.8656573] [0.30539232]
# 400 0.012151358 [0.87197095] [0.2910401]
# 420 0.011036054 [0.8779879] [0.27736226]
# 440 0.010023125 [0.88372195] [0.26432726]
# ...

# %%
## 직접 값을 주지않고, 필요할때 값을 던져주는 방법
W = tf.Variable(tf.random_normal([1], name='weight'))
b = tf.Variable(tf.random_normal([1], name='bias'))
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

# our hypothesis
hypothesis = X * W + b
# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))
# minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)                       

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train],
                                         feed_dict={X: [1, 2, 3, 4, 5],
                                                    Y: [2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 60.187416 [-0.8358409] [1.281686]
# 20 0.066984005 [0.8265892] [1.6969514]
# 40 0.05742668 [0.8449118] [1.659786]
# 60 0.050151102 [0.85510015] [1.6231338]
# 80 0.043797288 [0.8645899] [1.5888734]
# 100 0.038248546 [0.8734579] [1.5568569]
# 120 0.0334028 [0.8817453] [1.5269369]
# 140 0.02917085 [0.88948995] [1.4989763]
# 160 0.025475109 [0.8967273] [1.4728471]
# 180 0.022247631 [0.9034908] [1.4484289]
# 200 0.019428985 [0.9098112] [1.4256101]
# 220 0.016967515 [0.9157177] [1.4042857]
# 240 0.014817852 [0.9212374] [1.3843578]
# 260 0.012940568 [0.92639554] [1.3657352]
# 280 0.011301098 [0.93121594] [1.348332]
# 300 0.009869302 [0.93572074] [1.3320683]
# 320 0.00861894 [0.9399305] [1.3168699]
# 340 0.007526969 [0.9438645] [1.3026669]
# 360 0.0065733865 [0.9475408] [1.2893941]
# 380 0.0057405634 [0.95097643] [1.2769905]
# 400 0.005013276 [0.95418704] [1.2653991]
# 420 0.004378115 [0.9571874] [1.2545667]
# 440 0.0038234233 [0.95999134] [1.2444438]
# ...

# %%
# Testing out model
print(sess.run(hypothesis, feed_dict={X: [5]}))
print(sess.run(hypothesis, feed_dict={X: [2.5]}))
print(sess.run(hypothesis, feed_dict={X: [1.5, 3.5]}))
# Out:
# [6.099717]
# [3.6002254]
# [2.6004286 4.6000223]
